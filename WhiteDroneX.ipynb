# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")

# %%
b = model.predict("D:\Pics\P7.jpg")
# Out:
# image 1/1 D:\Pics\P7.jpg: 448x640 1 cat, 1 refrigerator, 936.5ms
# Speed: 15.6ms preprocess, 936.5ms inference, 15.6ms postprocess per image at shape (1, 3, 448, 640)

# %%
x = model.predict(["D:\Pics\P1.jpg", "D:\Pics\P2.jpg", "D:\Pics\P3.jpg"])
# Out:
# 0: 640x640 1 dog, 1: 640x640 1 dog, 1 horse, 2: 640x640 1 cat, 4321.1ms
# Speed: 0.0ms preprocess, 1440.4ms inference, 10.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
len(b[0].boxes)
# Out:
# 2

# %%
result = b[0]
box = result.boxes[0]

#Basic syntax for co-ordinates, class id and degree of confidence
raw_co_ord = box.xyxy[0].tolist()
co_ord = [round(x) for x in raw_co_ord]

class_id = result.names[box.cls[0].item()]

#Rounded to 2 decimal places
conf = round(box.conf[0].item(), 2)

# %%
print(co_ord)
print(class_id)
print(conf)
# Out:
# [11, 24, 192, 165]
# cat
# 0.96

# %%
model.train(data="D:\Drone\HostelDataset\data.yaml", epochs=6, batch = 5)
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.9.18 torch-2.1.1 CPU (Intel Core(TM) i5-6300U 2.40GHz)
# ...

# %%
b = model.predict("D:\Drone\HostelDataset\Test\images\H6.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 b = model.predict("D:\Drone\HostelDataset\Test\images\H6.jpg")
#
# NameError: name 'model' is not defined

# %%
result = b[0]
box = result.boxes[0]

#Basic syntax for co-ordinates, class id and degree of confidence
raw_co_ord = box.xyxy[0].tolist()
co_ord = [round(x) for x in raw_co_ord]

class_id = result.names[box.cls[0].item()]

#Rounded to 2 decimal places
conf = round(box.conf[0].item(), 2)

# %%
print(co_ord)
print(class_id)
print(conf)
# Out:
# [653, 539, 787, 602]
# X
# 0.95

# %%
b = model.predict("D:\Pics\P7.jpg")
# Out:
# image 1/1 D:\Pics\P7.jpg: 448x640 (no detections), 1003.2ms
# Speed: 8.0ms preprocess, 1003.2ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
b
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'X'}
#  orig_img: array([[[188, 182, 183],
#          [189, 183, 184],
#          [190, 184, 185],
#          ...,
#          [204, 202, 202],
#          [204, 202, 202],
#          [204, 202, 202]],
#
#         [[189, 183, 184],
#          [189, 183, 184],
#          [191, 185, 186],
#          ...,
#          [207, 205, 205],
#          [207, 205, 205],
#          [207, 205, 205]],
#
#         [[190, 184, 185],
#          [191, 185, 186],
#          [192, 186, 187],
#          ...,
#          [205, 203, 203],
#          [205, 203, 203],
#          [205, 203, 203]],
#
#         ...,
#
#         [[158, 160, 161],
#          [159, 161, 162],
#          [160, 162, 163],
#          ...,
#          [181, 180, 182],
#          [181, 180, 182],
#          [181, 180, 182]],
#
#         [[158, 160, 161],
#          [158, 160, 161],
# ...

# %%
import torch

# %%
torch.save(model.state_dict(), "D:\Drone\Model1.pth")

# %%
a = model.predict("D:\Drone\HostelDataset\Test\images\H17.jpg")
# Out:
# image 1/1 D:\Drone\HostelDataset\Test\images\H17.jpg: 640x384 2 Xs, 891.9ms
# Speed: 7.9ms preprocess, 891.9ms inference, 7.8ms postprocess per image at shape (1, 3, 640, 384)

# %%
result = a[0]
box = result.boxes[1]

#Basic syntax for co-ordinates, class id and degree of confidence
raw_co_ord = box.xyxy[0].tolist()
co_ord = [round(x) for x in raw_co_ord]

class_id = result.names[box.cls[0].item()]

#Rounded to 2 decimal places
conf = round(box.conf[0].item(), 2)

# %%
print(co_ord)
print(class_id)
print(conf)
# Out:
# [3, 57, 896, 1599]
# X
# 0.32

# %%
a[0].boxes[0]
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.5043])
# data: tensor([[4.1051e+02, 5.3367e+02, 5.6782e+02, 7.1046e+02, 5.0427e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1600, 900)
# shape: torch.Size([1, 6])
# xywh: tensor([[489.1656, 622.0662, 157.3168, 176.7831]])
# xywhn: tensor([[0.5435, 0.3888, 0.1748, 0.1105]])
# xyxy: tensor([[410.5073, 533.6746, 567.8240, 710.4577]])
# xyxyn: tensor([[0.4561, 0.3335, 0.6309, 0.4440]])
